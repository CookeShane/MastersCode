# %% [markdown]
# # Mask-RCNN Model Implemented using PyTorch

# %% [markdown]
# ***
#
# **Author:** Shane Cooke
#
# **Date:** 30 Sept 2022
#
# **References:**
# * https://medium.com/fullstackai/how-to-train-an-object-detector-with-your-own-coco-dataset-in-pytorch-319e7090da5
# * https://towardsdatascience.com/train-mask-rcnn-net-for-object-detection-in-60-lines-of-code-9b6bbff292c3
# * https://towardsdatascience.com/how-to-use-datasets-and-dataloader-in-pytorch-for-custom-text-data-270eed7f7c00
# * https://www.kaggle.com/code/abhishek/train-your-own-mask-rcnn/notebook
#
# ***

# %% [markdown]
# ## Imports & Data Preparation

# %% [markdown]
# #### Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/MastersProject/Code/
# Out:
# /content/drive/MyDrive/MastersProject/Code

# %% [markdown]
# #### Install Dependencies

# %%
#!pip install albumentations==0.4.6
#!pip install pycocotools --quiet

# Clone TorchVision repo and copy helper files
#!git clone https://github.com/pytorch/vision.git
#%cd vision
#!git checkout v0.3.0
#%cd ..
#!cp vision/references/detection/utils.py ./
#!cp vision/references/detection/transforms.py ./
#!cp vision/references/detection/coco_eval.py ./
#!cp vision/references/detection/engine.py ./
#!cp vision/references/detection/coco_utils.py ./

# %% [markdown]
# #### Imports

# %%
# Import Torch Libraries
import torch
import torchvision
from torchvision import models, transforms
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# Import Useful Libraries
import os
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# Import Image/File Work
from PIL import Image
import json
import numpy as np

# %% [markdown]
# #### Defining Input/Output Files & Directories

# %%
classes = ('NonOverfilled', 'Overfilled')
num_classes = 3
ds = "ASL" # ASL or FEL

# %% [markdown]
# #### Dataset Preparation

# %%
def DataPrep(image_path, annot_path):
   
    jpg_files = [pos_jpg for pos_jpg in os.listdir(image_path) if pos_jpg.endswith('.jpg')]
    
    with open(annot_path) as json_file:
        annotations = json.load(json_file)
    
    return jpg_files, annotations

# %%
class Dataset(torch.utils.data.Dataset):

    def __init__(self, imSize, imDir, imNames, annots, transforms=None):
        self.height = imSize[0]
        self.width = imSize[1]
        self.imDir = imDir
        self.imNames = imNames
        self.annots = annots
        self.transform = transforms
    
    def __getitem__(self, index):
        image_name = self.imNames[index]
        image_path = f"{self.imDir}{image_name}"

        image = Image.open(image_path).convert('RGB')
        image = image.resize((self.width, self.height), resample=Image.BILINEAR)

        for item in self.annots['images']:
            if item['file_name'] == image_name:
                imageID = item['id']
                break

        boxes = []
        area = []
        iscrowd = []
        labels = []
        masks = []
        
        for annotation in self.annots['annotations']:
            if annotation['image_id'] == imageID:
                xmin = annotation['bbox'][0]
                ymin = annotation['bbox'][1]
                xmax = xmin + annotation['bbox'][2]
                ymax = ymin + annotation['bbox'][3]
                
                # Append Values to Arrays
                area.append(annotation['area'])
                iscrowd.append(annotation['iscrowd'])
                labels.append(annotation['category_id'])
                boxes.append((xmin, ymin, xmax, ymax))
                #segmen.append(annotation['segmentation'])

        # Transform data into Tensor Format
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        imageID = torch.as_tensor(imageID, dtype=torch.int64) # torch.tensor([imageID])
        area = torch.as_tensor(area, dtype=torch.float32)
        iscrowd = torch.as_tensor(iscrowd, dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)
        
        targets = {}
        targets['boxes'] = boxes
        targets['labels'] = labels
        targets['image_id'] = imageID
        targets['area'] = area
        targets['iscrowd'] = iscrowd
        targets['masks'] = masks

        if self.transform is not None:
            image, targets = self.transform(image, targets)

        return image, targets

    def __len__(self):
        return len(self.imNames)

# %%
def get_transform():
    transforms = []
    transforms.append(T.ToTensor())
    return T.Compose(transforms)

# %% [markdown]
# #### Training Data Loader

# %%
image_path = f'./Dataset/{ds}/Train/'
annot_path = f'./Dataset/{ds}/{ds}_train_abs.json'
train_imNames, train_annotations = DataPrep(image_path, annot_path)
imSize = [480, 704]

train_data = Dataset(imSize, image_path, train_imNames, train_annotations, get_transform())
print('Length of dataset: ', len(train_data), '\n')

image, annotations = train_data[6]
print('Image shape: ', image.shape)                                                                   
print('Annotation Example: ', annotations)
print('Image type: ',image.dtype)

batchSize = 4
workers = 2
train_data_loader = torch.utils.data.DataLoader(train_data, batch_size=batchSize, shuffle=True, num_workers=workers, collate_fn=utils.collate_fn)
# Out:
# Length of dataset:  1602
#
# Image shape:  torch.Size([3, 480, 704])
# Annotation Example:  {'boxes': tensor([[316.9700, 242.5500, 464.1000, 442.1700],
#         [ 39.2200, 172.6700, 169.8400, 430.9600]]), 'labels': tensor([2, 2]), 'image_id': tensor(1416), 'area': tensor([29370.1094, 33738.3789]), 'iscrowd': tensor([0, 0])}
# Image type:  torch.float32

# %%
with open(annot_path) as json_file:
    annotations = json.load(json_file)

points = annotations['annotations'][1]['segmentation'][0]
points = tuple(points)

print(points)
# Out:
# (383.46, 198.1, 379.89, 216.15, 381.08, 217.74, 376.92, 235.39, 385.05, 240.55, 397.35, 241.74, 401.51, 221.11, 405.48, 221.91, 409.05, 212.78, 412.03, 211.79, 412.42, 207.43, 406.87, 203.06, 393.98, 198.1, 388.62, 197.51, 386.04, 195.92)

# %% [markdown]
# #### Validation Data Loader

# %%
image_path = f'./Dataset/{ds}/Val/'
annot_path = f'./Dataset/{ds}/{ds}_val_abs.json'
val_imNames, val_annotations = DataPrep(image_path, annot_path)
imSize = [480, 704]

val_data = Dataset(imSize, image_path, val_imNames, val_annotations, get_transform())

batchSize = 2
workers = 2
val_data_loader = torch.utils.data.DataLoader(val_data, batch_size=batchSize, shuffle=False, num_workers=workers, collate_fn=utils.collate_fn)

# %% [markdown]
# ***
# ## Training

# %% [markdown]
# #### Define Model

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print(device)
# Out:
# cuda

# %%
model = torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights=models.detection.MaskRCNN_ResNet50_FPN_V2_Weights.DEFAULT)
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = MaskRCNNPredictor(in_features, num_classes)
model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.02, momentum=0.9, weight_decay=0.0001)

lr_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[6,10], gamma=0.1)
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_v2_coco-73cbd019.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_v2_coco-73cbd019.pth
#   0%|          | 0.00/177M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6dd187802b6e> in <module>
#       4 model = torchvision.models.detection.maskrcnn_resnet50_fpn_v2(weights=models.detection.MaskRCNN_ResNet50_FPN_V2_Weights.DEFAULT)
#       5 in_features = model.roi_heads.box_predictor.cls_score.in_features
# ----> 6 model.roi_heads.box_predictor = MaskRCNNPredictor(in_features, num_classes)
#       7 model.to(device)
#       8
#
# TypeError: __init__() missing 1 required positional argument: 'num_classes'

# %% [markdown]
# #### Training Function

# %%
epochs = 5

for epoch in range(epochs):
    print("\n\n")
    train_one_epoch(model, optimizer, train_data_loader, device, epoch, print_freq=20)
    lr_scheduler.step()
    evaluate(model, val_data_loader, device=device)

torch.save(model, f'./Models/trained_{ds}_model_Epoch{epochs}.pt')

print('\n\nTraining is now finished')
# Out:
# Epoch: [0]  [  0/401]  eta: 1:20:11  lr: 0.000070  loss: 1.5091 (1.5091)  loss_classifier: 1.2319 (1.2319)  loss_box_reg: 0.2241 (0.2241)  loss_objectness: 0.0484 (0.0484)  loss_rpn_box_reg: 0.0046 (0.0046)  time: 11.9997  data: 1.9829  max mem: 7120
# Epoch: [0]  [ 20/401]  eta: 0:13:58  lr: 0.001069  loss: 0.6239 (0.8403)  loss_classifier: 0.3855 (0.6215)  loss_box_reg: 0.1455 (0.1637)  loss_objectness: 0.0334 (0.0491)  loss_rpn_box_reg: 0.0055 (0.0061)  time: 1.7101  data: 0.3700  max mem: 7731
# Epoch: [0]  [ 40/401]  eta: 0:10:47  lr: 0.002068  loss: 0.3886 (0.6321)  loss_classifier: 0.1959 (0.4151)  loss_box_reg: 0.1895 (0.1776)  loss_objectness: 0.0161 (0.0343)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 1.3687  data: 0.0150  max mem: 7731
# Epoch: [0]  [ 60/401]  eta: 0:09:26  lr: 0.003067  loss: 0.3096 (0.5264)  loss_classifier: 0.1041 (0.3151)  loss_box_reg: 0.1895 (0.1787)  loss_objectness: 0.0131 (0.0283)  loss_rpn_box_reg: 0.0019 (0.0043)  time: 1.3877  data: 0.0151  max mem: 7731
# Epoch: [0]  [ 80/401]  eta: 0:08:32  lr: 0.004066  loss: 0.2199 (0.4550)  loss_classifier: 0.0848 (0.2597)  loss_box_reg: 0.1225 (0.1680)  loss_objectness: 0.0089 (0.0238)  loss_rpn_box_reg: 0.0013 (0.0036)  time: 1.4006  data: 0.0148  max mem: 7731
# Epoch: [0]  [100/401]  eta: 0:07:50  lr: 0.005065  loss: 0.1510 (0.3989)  loss_classifier: 0.0669 (0.2234)  loss_box_reg: 0.0692 (0.1516)  loss_objectness: 0.0046 (0.0206)  loss_rpn_box_reg: 0.0013 (0.0033)  time: 1.4235  data: 0.0198  max mem: 7731
# Epoch: [0]  [120/401]  eta: 0:07:12  lr: 0.006064  loss: 0.1367 (0.3566)  loss_classifier: 0.0691 (0.1984)  loss_box_reg: 0.0592 (0.1370)  loss_objectness: 0.0048 (0.0182)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 1.4233  data: 0.0151  max mem: 7731
# Epoch: [0]  [140/401]  eta: 0:06:37  lr: 0.007063  loss: 0.1093 (0.3252)  loss_classifier: 0.0509 (0.1787)  loss_box_reg: 0.0606 (0.1271)  loss_objectness: 0.0042 (0.0165)  loss_rpn_box_reg: 0.0012 (0.0029)  time: 1.4325  data: 0.0150  max mem: 7731
# Epoch: [0]  [160/401]  eta: 0:06:04  lr: 0.008062  loss: 0.1034 (0.3005)  loss_classifier: 0.0488 (0.1636)  loss_box_reg: 0.0576 (0.1188)  loss_objectness: 0.0031 (0.0154)  loss_rpn_box_reg: 0.0012 (0.0027)  time: 1.4407  data: 0.0147  max mem: 7731
# Epoch: [0]  [180/401]  eta: 0:05:32  lr: 0.009061  loss: 0.1240 (0.2811)  loss_classifier: 0.0526 (0.1521)  loss_box_reg: 0.0600 (0.1124)  loss_objectness: 0.0033 (0.0141)  loss_rpn_box_reg: 0.0015 (0.0026)  time: 1.4491  data: 0.0151  max mem: 7731
# Epoch: [0]  [200/401]  eta: 0:05:01  lr: 0.010060  loss: 0.1329 (0.2671)  loss_classifier: 0.0554 (0.1433)  loss_box_reg: 0.0545 (0.1077)  loss_objectness: 0.0060 (0.0136)  loss_rpn_box_reg: 0.0015 (0.0025)  time: 1.4543  data: 0.0149  max mem: 7731
# Epoch: [0]  [220/401]  eta: 0:04:31  lr: 0.011059  loss: 0.1054 (0.2539)  loss_classifier: 0.0570 (0.1355)  loss_box_reg: 0.0533 (0.1033)  loss_objectness: 0.0022 (0.0127)  loss_rpn_box_reg: 0.0013 (0.0024)  time: 1.4542  data: 0.0150  max mem: 7731
# Epoch: [0]  [240/401]  eta: 0:04:00  lr: 0.012058  loss: 0.0965 (0.2407)  loss_classifier: 0.0347 (0.1279)  loss_box_reg: 0.0337 (0.0985)  loss_objectness: 0.0013 (0.0119)  loss_rpn_box_reg: 0.0008 (0.0023)  time: 1.4610  data: 0.0157  max mem: 7731
# Epoch: [0]  [260/401]  eta: 0:03:30  lr: 0.013057  loss: 0.0872 (0.2293)  loss_classifier: 0.0344 (0.1212)  loss_box_reg: 0.0454 (0.0947)  loss_objectness: 0.0011 (0.0112)  loss_rpn_box_reg: 0.0006 (0.0022)  time: 1.4675  data: 0.0173  max mem: 7731
# Epoch: [0]  [280/401]  eta: 0:03:00  lr: 0.014056  loss: 0.0998 (0.2208)  loss_classifier: 0.0427 (0.1162)  loss_box_reg: 0.0501 (0.0919)  loss_objectness: 0.0011 (0.0105)  loss_rpn_box_reg: 0.0009 (0.0021)  time: 1.4644  data: 0.0150  max mem: 7731
# Epoch: [0]  [300/401]  eta: 0:02:30  lr: 0.015055  loss: 0.0828 (0.2129)  loss_classifier: 0.0328 (0.1115)  loss_box_reg: 0.0442 (0.0892)  loss_objectness: 0.0010 (0.0101)  loss_rpn_box_reg: 0.0008 (0.0021)  time: 1.4677  data: 0.0145  max mem: 7731
# Epoch: [0]  [320/401]  eta: 0:02:00  lr: 0.016054  loss: 0.0978 (0.2068)  loss_classifier: 0.0480 (0.1083)  loss_box_reg: 0.0415 (0.0868)  loss_objectness: 0.0020 (0.0097)  loss_rpn_box_reg: 0.0009 (0.0020)  time: 1.4700  data: 0.0154  max mem: 7731
# Epoch: [0]  [340/401]  eta: 0:01:30  lr: 0.017053  loss: 0.1031 (0.2015)  loss_classifier: 0.0477 (0.1053)  loss_box_reg: 0.0438 (0.0849)  loss_objectness: 0.0014 (0.0093)  loss_rpn_box_reg: 0.0011 (0.0020)  time: 1.4710  data: 0.0151  max mem: 7731
# Epoch: [0]  [360/401]  eta: 0:01:00  lr: 0.018052  loss: 0.0997 (0.1965)  loss_classifier: 0.0434 (0.1024)  loss_box_reg: 0.0498 (0.0833)  loss_objectness: 0.0016 (0.0089)  loss_rpn_box_reg: 0.0012 (0.0020)  time: 1.4721  data: 0.0148  max mem: 7731
# Epoch: [0]  [380/401]  eta: 0:00:31  lr: 0.019051  loss: 0.1038 (0.1920)  loss_classifier: 0.0535 (0.0997)  loss_box_reg: 0.0514 (0.0817)  loss_objectness: 0.0009 (0.0086)  loss_rpn_box_reg: 0.0010 (0.0020)  time: 1.4742  data: 0.0156  max mem: 7731
# Epoch: [0]  [400/401]  eta: 0:00:01  lr: 0.020000  loss: 0.0839 (0.1873)  loss_classifier: 0.0363 (0.0969)  loss_box_reg: 0.0375 (0.0802)  loss_objectness: 0.0018 (0.0083)  loss_rpn_box_reg: 0.0009 (0.0019)  time: 1.4379  data: 0.0144  max mem: 7731
# Epoch: [0] Total time: 0:09:54 (1.4830 s / it)
# creating index...
# index created!
# Test:  [ 0/90]  eta: 0:00:45  model_time: 0.3579 (0.3579)  evaluator_time: 0.0049 (0.0049)  time: 0.5035  data: 0.1377  max mem: 7731
# Test:  [89/90]  eta: 0:00:00  model_time: 0.2980 (0.2964)  evaluator_time: 0.0016 (0.0017)  time: 0.3109  data: 0.0080  max mem: 7731
# Test: Total time: 0:00:27 (0.3110 s / it)
# Averaged stats: model_time: 0.2980 (0.2964)  evaluator_time: 0.0016 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.705
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.941
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.841
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.791
#
#
#
# Epoch: [1]  [  0/401]  eta: 0:10:58  lr: 0.020000  loss: 0.0820 (0.0820)  loss_classifier: 0.0352 (0.0352)  loss_box_reg: 0.0450 (0.0450)  loss_objectness: 0.0012 (0.0012)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.6424  data: 0.2404  max mem: 7731
# Epoch: [1]  [ 20/401]  eta: 0:09:01  lr: 0.020000  loss: 0.0676 (0.0796)  loss_classifier: 0.0223 (0.0334)  loss_box_reg: 0.0422 (0.0439)  loss_objectness: 0.0005 (0.0014)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.4116  data: 0.0143  max mem: 7731
# Epoch: [1]  [ 40/401]  eta: 0:08:33  lr: 0.020000  loss: 0.0644 (0.0758)  loss_classifier: 0.0265 (0.0342)  loss_box_reg: 0.0335 (0.0397)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 1.4227  data: 0.0147  max mem: 7731
# Epoch: [1]  [ 60/401]  eta: 0:08:06  lr: 0.020000  loss: 0.0666 (0.0800)  loss_classifier: 0.0302 (0.0373)  loss_box_reg: 0.0397 (0.0409)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.4335  data: 0.0153  max mem: 7731
# Epoch: [1]  [ 80/401]  eta: 0:07:38  lr: 0.020000  loss: 0.0571 (0.0773)  loss_classifier: 0.0242 (0.0357)  loss_box_reg: 0.0322 (0.0399)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0004 (0.0008)  time: 1.4385  data: 0.0146  max mem: 7731
# Epoch: [1]  [100/401]  eta: 0:07:11  lr: 0.020000  loss: 0.0788 (0.0798)  loss_classifier: 0.0385 (0.0371)  loss_box_reg: 0.0415 (0.0408)  loss_objectness: 0.0006 (0.0010)  loss_rpn_box_reg: 0.0010 (0.0009)  time: 1.4537  data: 0.0164  max mem: 7731
# Epoch: [1]  [120/401]  eta: 0:06:43  lr: 0.020000  loss: 0.0864 (0.0820)  loss_classifier: 0.0316 (0.0379)  loss_box_reg: 0.0454 (0.0421)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 1.4518  data: 0.0147  max mem: 7731
# Epoch: [1]  [140/401]  eta: 0:06:15  lr: 0.020000  loss: 0.0936 (0.0829)  loss_classifier: 0.0325 (0.0382)  loss_box_reg: 0.0406 (0.0427)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 1.4565  data: 0.0149  max mem: 7731
# Epoch: [1]  [160/401]  eta: 0:05:47  lr: 0.020000  loss: 0.0600 (0.0819)  loss_classifier: 0.0250 (0.0373)  loss_box_reg: 0.0323 (0.0422)  loss_objectness: 0.0003 (0.0013)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4627  data: 0.0146  max mem: 7731
# Epoch: [1]  [180/401]  eta: 0:05:19  lr: 0.020000  loss: 0.0602 (0.0821)  loss_classifier: 0.0273 (0.0377)  loss_box_reg: 0.0298 (0.0419)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4701  data: 0.0151  max mem: 7731
# Epoch: [1]  [200/401]  eta: 0:04:51  lr: 0.020000  loss: 0.0809 (0.0821)  loss_classifier: 0.0334 (0.0379)  loss_box_reg: 0.0374 (0.0418)  loss_objectness: 0.0010 (0.0015)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4726  data: 0.0152  max mem: 7731
# Epoch: [1]  [220/401]  eta: 0:04:22  lr: 0.020000  loss: 0.0713 (0.0819)  loss_classifier: 0.0271 (0.0377)  loss_box_reg: 0.0371 (0.0418)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4742  data: 0.0152  max mem: 7731
# Epoch: [1]  [240/401]  eta: 0:03:53  lr: 0.020000  loss: 0.0795 (0.0829)  loss_classifier: 0.0313 (0.0378)  loss_box_reg: 0.0454 (0.0424)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0009 (0.0010)  time: 1.4750  data: 0.0153  max mem: 7731
# Epoch: [1]  [260/401]  eta: 0:03:25  lr: 0.020000  loss: 0.0701 (0.0827)  loss_classifier: 0.0303 (0.0377)  loss_box_reg: 0.0337 (0.0422)  loss_objectness: 0.0013 (0.0017)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4790  data: 0.0168  max mem: 7731
# Epoch: [1]  [280/401]  eta: 0:02:56  lr: 0.020000  loss: 0.0623 (0.0821)  loss_classifier: 0.0240 (0.0374)  loss_box_reg: 0.0371 (0.0419)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0007 (0.0010)  time: 1.4721  data: 0.0147  max mem: 7731
# Epoch: [1]  [300/401]  eta: 0:02:27  lr: 0.020000  loss: 0.0631 (0.0811)  loss_classifier: 0.0234 (0.0369)  loss_box_reg: 0.0316 (0.0415)  loss_objectness: 0.0004 (0.0017)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 1.4732  data: 0.0154  max mem: 7731
# Epoch: [1]  [320/401]  eta: 0:01:58  lr: 0.020000  loss: 0.0918 (0.0818)  loss_classifier: 0.0357 (0.0370)  loss_box_reg: 0.0451 (0.0420)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0008 (0.0010)  time: 1.4737  data: 0.0145  max mem: 7731
# Epoch: [1]  [340/401]  eta: 0:01:29  lr: 0.020000  loss: 0.0590 (0.0812)  loss_classifier: 0.0262 (0.0368)  loss_box_reg: 0.0319 (0.0418)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 1.4734  data: 0.0147  max mem: 7731
# Epoch: [1]  [360/401]  eta: 0:00:59  lr: 0.020000  loss: 0.0614 (0.0812)  loss_classifier: 0.0262 (0.0369)  loss_box_reg: 0.0342 (0.0417)  loss_objectness: 0.0004 (0.0017)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 1.4743  data: 0.0156  max mem: 7731
# Epoch: [1]  [380/401]  eta: 0:00:30  lr: 0.020000  loss: 0.0696 (0.0814)  loss_classifier: 0.0322 (0.0370)  loss_box_reg: 0.0358 (0.0418)  loss_objectness: 0.0004 (0.0016)  loss_rpn_box_reg: 0.0010 (0.0010)  time: 1.4760  data: 0.0156  max mem: 7731
# Epoch: [1]  [400/401]  eta: 0:00:01  lr: 0.020000  loss: 0.0633 (0.0807)  loss_classifier: 0.0260 (0.0366)  loss_box_reg: 0.0327 (0.0415)  loss_objectness: 0.0004 (0.0016)  loss_rpn_box_reg: 0.0006 (0.0010)  time: 1.4442  data: 0.0168  max mem: 7731
# Epoch: [1] Total time: 0:09:45 (1.4601 s / it)
# creating index...
# index created!
# Test:  [ 0/90]  eta: 0:00:40  model_time: 0.3106 (0.3106)  evaluator_time: 0.0027 (0.0027)  time: 0.4522  data: 0.1323  max mem: 7731
# Test:  [89/90]  eta: 0:00:00  model_time: 0.3135 (0.3135)  evaluator_time: 0.0019 (0.0019)  time: 0.3268  data: 0.0084  max mem: 7731
# Test: Total time: 0:00:29 (0.3285 s / it)
# Averaged stats: model_time: 0.3135 (0.3135)  evaluator_time: 0.0019 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.791
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.929
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.777
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.677
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.694
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.845
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.845
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.851
#
#
#
# Epoch: [2]  [  0/401]  eta: 0:11:17  lr: 0.020000  loss: 0.0584 (0.0584)  loss_classifier: 0.0355 (0.0355)  loss_box_reg: 0.0214 (0.0214)  loss_objectness: 0.0011 (0.0011)  loss_rpn_box_reg: 0.0003 (0.0003)  time: 1.6885  data: 0.2320  max mem: 7731
# Epoch: [2]  [ 20/401]  eta: 0:09:25  lr: 0.020000  loss: 0.0466 (0.0502)  loss_classifier: 0.0183 (0.0236)  loss_box_reg: 0.0272 (0.0256)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4728  data: 0.0141  max mem: 7731
# Epoch: [2]  [ 40/401]  eta: 0:08:53  lr: 0.020000  loss: 0.0422 (0.0484)  loss_classifier: 0.0147 (0.0206)  loss_box_reg: 0.0254 (0.0267)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.4726  data: 0.0150  max mem: 7731
# Epoch: [2]  [ 60/401]  eta: 0:08:23  lr: 0.020000  loss: 0.0462 (0.0493)  loss_classifier: 0.0162 (0.0206)  loss_box_reg: 0.0266 (0.0276)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.4741  data: 0.0157  max mem: 7731
# Epoch: [2]  [ 80/401]  eta: 0:07:53  lr: 0.020000  loss: 0.0378 (0.0520)  loss_classifier: 0.0136 (0.0229)  loss_box_reg: 0.0208 (0.0279)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4731  data: 0.0149  max mem: 7731
# Epoch: [2]  [100/401]  eta: 0:07:24  lr: 0.020000  loss: 0.0466 (0.0524)  loss_classifier: 0.0177 (0.0229)  loss_box_reg: 0.0235 (0.0283)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4737  data: 0.0151  max mem: 7731
# Epoch: [2]  [120/401]  eta: 0:06:54  lr: 0.020000  loss: 0.0462 (0.0535)  loss_classifier: 0.0159 (0.0229)  loss_box_reg: 0.0275 (0.0293)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.4740  data: 0.0146  max mem: 7731
# Epoch: [2]  [140/401]  eta: 0:06:25  lr: 0.020000  loss: 0.0431 (0.0529)  loss_classifier: 0.0148 (0.0225)  loss_box_reg: 0.0255 (0.0292)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4790  data: 0.0171  max mem: 7731
# Epoch: [2]  [160/401]  eta: 0:05:55  lr: 0.020000  loss: 0.0447 (0.0532)  loss_classifier: 0.0176 (0.0225)  loss_box_reg: 0.0268 (0.0295)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4737  data: 0.0154  max mem: 7731
# Epoch: [2]  [180/401]  eta: 0:05:26  lr: 0.020000  loss: 0.0464 (0.0535)  loss_classifier: 0.0178 (0.0227)  loss_box_reg: 0.0248 (0.0295)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.4742  data: 0.0154  max mem: 7731
# Epoch: [2]  [200/401]  eta: 0:04:56  lr: 0.020000  loss: 0.0538 (0.0542)  loss_classifier: 0.0246 (0.0235)  loss_box_reg: 0.0206 (0.0294)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.4740  data: 0.0148  max mem: 7731
# Epoch: [2]  [220/401]  eta: 0:04:27  lr: 0.020000  loss: 0.0459 (0.0540)  loss_classifier: 0.0215 (0.0233)  loss_box_reg: 0.0262 (0.0295)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4747  data: 0.0146  max mem: 7731
# Epoch: [2]  [240/401]  eta: 0:03:57  lr: 0.020000  loss: 0.0588 (0.0552)  loss_classifier: 0.0225 (0.0238)  loss_box_reg: 0.0322 (0.0301)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.4729  data: 0.0150  max mem: 7731
# Epoch: [2]  [260/401]  eta: 0:03:27  lr: 0.020000  loss: 0.0552 (0.0558)  loss_classifier: 0.0237 (0.0243)  loss_box_reg: 0.0300 (0.0302)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.4754  data: 0.0153  max mem: 7731
# Epoch: [2]  [280/401]  eta: 0:02:58  lr: 0.020000  loss: 0.0653 (0.0567)  loss_classifier: 0.0223 (0.0245)  loss_box_reg: 0.0343 (0.0310)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0007)  time: 1.4823  data: 0.0164  max mem: 7731
# Epoch: [2]  [300/401]  eta: 0:02:29  lr: 0.020000  loss: 0.0538 (0.0566)  loss_classifier: 0.0173 (0.0241)  loss_box_reg: 0.0345 (0.0312)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0007)  time: 1.4769  data: 0.0157  max mem: 7731
# Epoch: [2]  [320/401]  eta: 0:01:59  lr: 0.020000  loss: 0.0333 (0.0561)  loss_classifier: 0.0132 (0.0236)  loss_box_reg: 0.0206 (0.0311)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.4765  data: 0.0154  max mem: 7731
# Epoch: [2]  [340/401]  eta: 0:01:30  lr: 0.020000  loss: 0.0425 (0.0559)  loss_classifier: 0.0153 (0.0236)  loss_box_reg: 0.0227 (0.0309)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.4730  data: 0.0158  max mem: 7731
# Epoch: [2]  [360/401]  eta: 0:01:00  lr: 0.020000  loss: 0.0636 (0.0568)  loss_classifier: 0.0259 (0.0240)  loss_box_reg: 0.0348 (0.0314)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.4726  data: 0.0151  max mem: 7731
# Epoch: [2]  [380/401]  eta: 0:00:30  lr: 0.020000  loss: 0.0565 (0.0569)  loss_classifier: 0.0250 (0.0242)  loss_box_reg: 0.0267 (0.0314)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.4752  data: 0.0154  max mem: 7731
# Epoch: [2]  [400/401]  eta: 0:00:01  lr: 0.020000  loss: 0.0523 (0.0571)  loss_classifier: 0.0209 (0.0242)  loss_box_reg: 0.0277 (0.0314)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.4381  data: 0.0143  max mem: 7731
# Epoch: [2] Total time: 0:09:50 (1.4737 s / it)
# creating index...
# index created!
# Test:  [ 0/90]  eta: 0:00:41  model_time: 0.3114 (0.3114)  evaluator_time: 0.0031 (0.0031)  time: 0.4601  data: 0.1424  max mem: 7731
# Test:  [89/90]  eta: 0:00:00  model_time: 0.3129 (0.3138)  evaluator_time: 0.0024 (0.0020)  time: 0.3341  data: 0.0144  max mem: 7731
# Test: Total time: 0:00:29 (0.3308 s / it)
# Averaged stats: model_time: 0.3129 (0.3138)  evaluator_time: 0.0024 (0.0020)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.814
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.970
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.931
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.672
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.862
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.775
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.870
#
#
#
# Epoch: [3]  [  0/401]  eta: 0:11:10  lr: 0.020000  loss: 0.0617 (0.0617)  loss_classifier: 0.0239 (0.0239)  loss_box_reg: 0.0372 (0.0372)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.6711  data: 0.2153  max mem: 7731
# Epoch: [3]  [ 20/401]  eta: 0:09:25  lr: 0.020000  loss: 0.0468 (0.0513)  loss_classifier: 0.0156 (0.0232)  loss_box_reg: 0.0219 (0.0269)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4759  data: 0.0154  max mem: 7731
# Epoch: [3]  [ 40/401]  eta: 0:08:54  lr: 0.020000  loss: 0.0344 (0.0477)  loss_classifier: 0.0120 (0.0196)  loss_box_reg: 0.0208 (0.0269)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4754  data: 0.0156  max mem: 7731
# Epoch: [3]  [ 60/401]  eta: 0:08:24  lr: 0.020000  loss: 0.0366 (0.0468)  loss_classifier: 0.0129 (0.0188)  loss_box_reg: 0.0235 (0.0270)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4749  data: 0.0149  max mem: 7731
# Epoch: [3]  [ 80/401]  eta: 0:07:54  lr: 0.020000  loss: 0.0403 (0.0453)  loss_classifier: 0.0160 (0.0179)  loss_box_reg: 0.0247 (0.0264)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4756  data: 0.0152  max mem: 7731
# Epoch: [3]  [100/401]  eta: 0:07:24  lr: 0.020000  loss: 0.0287 (0.0437)  loss_classifier: 0.0115 (0.0173)  loss_box_reg: 0.0188 (0.0255)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 1.4759  data: 0.0152  max mem: 7731
# Epoch: [3]  [120/401]  eta: 0:06:55  lr: 0.020000  loss: 0.0376 (0.0444)  loss_classifier: 0.0129 (0.0174)  loss_box_reg: 0.0231 (0.0261)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4745  data: 0.0158  max mem: 7731
# Epoch: [3]  [140/401]  eta: 0:06:25  lr: 0.020000  loss: 0.0349 (0.0446)  loss_classifier: 0.0122 (0.0175)  loss_box_reg: 0.0225 (0.0262)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4765  data: 0.0153  max mem: 7731
# Epoch: [3]  [160/401]  eta: 0:05:56  lr: 0.020000  loss: 0.0409 (0.0447)  loss_classifier: 0.0153 (0.0175)  loss_box_reg: 0.0254 (0.0262)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4829  data: 0.0170  max mem: 7731
# Epoch: [3]  [180/401]  eta: 0:05:26  lr: 0.020000  loss: 0.0428 (0.0456)  loss_classifier: 0.0139 (0.0176)  loss_box_reg: 0.0276 (0.0270)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.4774  data: 0.0157  max mem: 7731
# Epoch: [3]  [200/401]  eta: 0:04:56  lr: 0.020000  loss: 0.0294 (0.0447)  loss_classifier: 0.0098 (0.0174)  loss_box_reg: 0.0178 (0.0264)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4774  data: 0.0149  max mem: 7731
# Epoch: [3]  [220/401]  eta: 0:04:27  lr: 0.020000  loss: 0.0329 (0.0440)  loss_classifier: 0.0119 (0.0174)  loss_box_reg: 0.0169 (0.0257)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 1.4756  data: 0.0155  max mem: 7731
# Epoch: [3]  [240/401]  eta: 0:03:57  lr: 0.020000  loss: 0.0405 (0.0439)  loss_classifier: 0.0148 (0.0172)  loss_box_reg: 0.0269 (0.0258)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4754  data: 0.0154  max mem: 7731
# Epoch: [3]  [260/401]  eta: 0:03:28  lr: 0.020000  loss: 0.0405 (0.0447)  loss_classifier: 0.0160 (0.0177)  loss_box_reg: 0.0222 (0.0260)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.4746  data: 0.0154  max mem: 7731
# Epoch: [3]  [280/401]  eta: 0:02:58  lr: 0.020000  loss: 0.0419 (0.0446)  loss_classifier: 0.0155 (0.0175)  loss_box_reg: 0.0253 (0.0262)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4754  data: 0.0149  max mem: 7731
# Epoch: [3]  [300/401]  eta: 0:02:29  lr: 0.020000  loss: 0.0353 (0.0446)  loss_classifier: 0.0120 (0.0175)  loss_box_reg: 0.0211 (0.0261)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4771  data: 0.0151  max mem: 7731
# Epoch: [3]  [320/401]  eta: 0:01:59  lr: 0.020000  loss: 0.0391 (0.0445)  loss_classifier: 0.0132 (0.0175)  loss_box_reg: 0.0233 (0.0261)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0002 (0.0006)  time: 1.4802  data: 0.0176  max mem: 7731
# Epoch: [3]  [340/401]  eta: 0:01:30  lr: 0.020000  loss: 0.0399 (0.0450)  loss_classifier: 0.0154 (0.0178)  loss_box_reg: 0.0211 (0.0262)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0006)  time: 1.4734  data: 0.0149  max mem: 7731
# Epoch: [3]  [360/401]  eta: 0:01:00  lr: 0.020000  loss: 0.0400 (0.0449)  loss_classifier: 0.0139 (0.0177)  loss_box_reg: 0.0234 (0.0262)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.4719  data: 0.0153  max mem: 7731
# Epoch: [3]  [380/401]  eta: 0:00:31  lr: 0.020000  loss: 0.0497 (0.0452)  loss_classifier: 0.0153 (0.0177)  loss_box_reg: 0.0285 (0.0265)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4738  data: 0.0148  max mem: 7731
# Epoch: [3]  [400/401]  eta: 0:00:01  lr: 0.020000  loss: 0.0360 (0.0453)  loss_classifier: 0.0118 (0.0178)  loss_box_reg: 0.0227 (0.0266)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0004 (0.0006)  time: 1.4417  data: 0.0149  max mem: 7731
# Epoch: [3] Total time: 0:09:51 (1.4750 s / it)
# creating index...
# index created!
# Test:  [ 0/90]  eta: 0:00:46  model_time: 0.3553 (0.3553)  evaluator_time: 0.0038 (0.0038)  time: 0.5214  data: 0.1592  max mem: 7731
# Test:  [89/90]  eta: 0:00:00  model_time: 0.3128 (0.3135)  evaluator_time: 0.0016 (0.0016)  time: 0.3263  data: 0.0083  max mem: 7731
# Test: Total time: 0:00:29 (0.3285 s / it)
# Averaged stats: model_time: 0.3128 (0.3135)  evaluator_time: 0.0016 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.971
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.923
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.779
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.833
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.719
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.869
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.876
#
#
#
# Epoch: [4]  [  0/401]  eta: 0:11:30  lr: 0.020000  loss: 0.0545 (0.0545)  loss_classifier: 0.0191 (0.0191)  loss_box_reg: 0.0339 (0.0339)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.7216  data: 0.2579  max mem: 7731
# Epoch: [4]  [ 20/401]  eta: 0:09:26  lr: 0.020000  loss: 0.0306 (0.0370)  loss_classifier: 0.0136 (0.0135)  loss_box_reg: 0.0164 (0.0224)  loss_objectness: 0.0001 (0.0006)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4749  data: 0.0143  max mem: 7731
# Epoch: [4]  [ 40/401]  eta: 0:08:56  lr: 0.020000  loss: 0.0278 (0.0368)  loss_classifier: 0.0098 (0.0130)  loss_box_reg: 0.0191 (0.0229)  loss_objectness: 0.0002 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4854  data: 0.0174  max mem: 7731
# Epoch: [4]  [ 60/401]  eta: 0:08:25  lr: 0.020000  loss: 0.0342 (0.0377)  loss_classifier: 0.0139 (0.0144)  loss_box_reg: 0.0194 (0.0224)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4775  data: 0.0162  max mem: 7731
# Epoch: [4]  [ 80/401]  eta: 0:07:55  lr: 0.020000  loss: 0.0410 (0.0390)  loss_classifier: 0.0131 (0.0147)  loss_box_reg: 0.0221 (0.0234)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4786  data: 0.0157  max mem: 7731
# Epoch: [4]  [100/401]  eta: 0:07:25  lr: 0.020000  loss: 0.0382 (0.0383)  loss_classifier: 0.0129 (0.0144)  loss_box_reg: 0.0205 (0.0230)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.4749  data: 0.0154  max mem: 7731
# Epoch: [4]  [120/401]  eta: 0:06:55  lr: 0.020000  loss: 0.0360 (0.0382)  loss_classifier: 0.0097 (0.0141)  loss_box_reg: 0.0219 (0.0231)  loss_objectness: 0.0001 (0.0004)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4736  data: 0.0144  max mem: 7731
# Epoch: [4]  [140/401]  eta: 0:06:25  lr: 0.020000  loss: 0.0380 (0.0388)  loss_classifier: 0.0110 (0.0144)  loss_box_reg: 0.0234 (0.0236)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0005 (0.0005)  time: 1.4724  data: 0.0148  max mem: 7731
# Epoch: [4]  [160/401]  eta: 0:05:56  lr: 0.020000  loss: 0.0327 (0.0386)  loss_classifier: 0.0112 (0.0143)  loss_box_reg: 0.0191 (0.0235)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4741  data: 0.0153  max mem: 7731
# Epoch: [4]  [180/401]  eta: 0:05:26  lr: 0.020000  loss: 0.0339 (0.0382)  loss_classifier: 0.0097 (0.0140)  loss_box_reg: 0.0199 (0.0234)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4747  data: 0.0149  max mem: 7731
# Epoch: [4]  [200/401]  eta: 0:04:57  lr: 0.020000  loss: 0.0343 (0.0379)  loss_classifier: 0.0110 (0.0140)  loss_box_reg: 0.0188 (0.0231)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4853  data: 0.0180  max mem: 7731
# Epoch: [4]  [220/401]  eta: 0:04:27  lr: 0.020000  loss: 0.0327 (0.0377)  loss_classifier: 0.0124 (0.0140)  loss_box_reg: 0.0178 (0.0230)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4728  data: 0.0150  max mem: 7731
# Epoch: [4]  [240/401]  eta: 0:03:57  lr: 0.020000  loss: 0.0295 (0.0377)  loss_classifier: 0.0108 (0.0141)  loss_box_reg: 0.0190 (0.0229)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4763  data: 0.0154  max mem: 7731
# Epoch: [4]  [260/401]  eta: 0:03:28  lr: 0.020000  loss: 0.0309 (0.0372)  loss_classifier: 0.0108 (0.0140)  loss_box_reg: 0.0164 (0.0225)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4752  data: 0.0153  max mem: 7731
# Epoch: [4]  [280/401]  eta: 0:02:58  lr: 0.020000  loss: 0.0333 (0.0369)  loss_classifier: 0.0111 (0.0138)  loss_box_reg: 0.0218 (0.0224)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4769  data: 0.0150  max mem: 7731
# Epoch: [4]  [300/401]  eta: 0:02:29  lr: 0.020000  loss: 0.0250 (0.0364)  loss_classifier: 0.0073 (0.0135)  loss_box_reg: 0.0150 (0.0222)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4767  data: 0.0157  max mem: 7731
# Epoch: [4]  [320/401]  eta: 0:01:59  lr: 0.020000  loss: 0.0268 (0.0364)  loss_classifier: 0.0096 (0.0135)  loss_box_reg: 0.0168 (0.0222)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4739  data: 0.0153  max mem: 7731
# Epoch: [4]  [340/401]  eta: 0:01:30  lr: 0.020000  loss: 0.0288 (0.0363)  loss_classifier: 0.0107 (0.0134)  loss_box_reg: 0.0205 (0.0222)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4760  data: 0.0163  max mem: 7731
# Epoch: [4]  [360/401]  eta: 0:01:00  lr: 0.020000  loss: 0.0332 (0.0365)  loss_classifier: 0.0111 (0.0136)  loss_box_reg: 0.0189 (0.0222)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4760  data: 0.0163  max mem: 7731
# Epoch: [4]  [380/401]  eta: 0:00:31  lr: 0.020000  loss: 0.0328 (0.0365)  loss_classifier: 0.0126 (0.0136)  loss_box_reg: 0.0184 (0.0221)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0003 (0.0005)  time: 1.4745  data: 0.0149  max mem: 7731
# Epoch: [4]  [400/401]  eta: 0:00:01  lr: 0.020000  loss: 0.0339 (0.0365)  loss_classifier: 0.0105 (0.0136)  loss_box_reg: 0.0195 (0.0221)  loss_objectness: 0.0001 (0.0003)  loss_rpn_box_reg: 0.0004 (0.0005)  time: 1.4411  data: 0.0144  max mem: 7731
# Epoch: [4] Total time: 0:09:51 (1.4753 s / it)
# creating index...
# index created!
# Test:  [ 0/90]  eta: 0:00:43  model_time: 0.3211 (0.3211)  evaluator_time: 0.0030 (0.0030)  time: 0.4824  data: 0.1547  max mem: 7731
# Test:  [89/90]  eta: 0:00:00  model_time: 0.3132 (0.3135)  evaluator_time: 0.0015 (0.0016)  time: 0.3259  data: 0.0081  max mem: 7731
# Test: Total time: 0:00:29 (0.3284 s / it)
# Averaged stats: model_time: 0.3132 (0.3135)  evaluator_time: 0.0015 (0.0016)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.826
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.965
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.937
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.628
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.838
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.722
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.870
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.683
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.769
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.878
#
#
# Training is now finished
